# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img = cv2.imread('spiderman.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (600, 698, 3)

# %%
cv2.imshow('title', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# to close it click at anywhere in img then press any key of keyboard

# %%
img1 = plt.imread('wp8.jpg')
plt.imshow(img1)

# %%
img2 = ski.io.imread('wp8.jpg')
ski.io.imshow(img2)

# %%
ski.io.imsave('myFile.png', img)

# %%
plt.imsave('myFile2.png', img)

# %%
cv2.imwrite('myFile3.png', img)
# Out:
# True

# %%
cv2.COLOR_RGB2GRAY
# function ko number de rakhe hai
# Out:
# 7

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
ski.io.imshow(img_gray)

# %%
_, img_binary = cv2.threshold(img_gray, 50, 255, cv2.THRESH_BINARY)
ski.io.imshow(img_binary)

# %%
print(_)
# Out:
# 50.0

# %%
cv2.__version__
# Out:
# '4.7.0'

# %% [markdown]
# # Day 2 Image Processing

# %%
import cv2
import matplotlib.pyplot as plt
from time import sleep

# %%
vid = cv2.VideoCapture(0)
vid
# Out:
# < cv2.VideoCapture 000001A4A0B519B0>

# %%
vid.isOpened()
# Out:
# True

# %%
i,k = vid.read()
i
# Out:
# True

# %%
type(k), len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[112,  93,  76],
#          [ 99,  83,  59],
#          [ 95,  83,  57],
#          ...,
#          [165, 142, 150],
#          [173, 145, 148],
#          [167, 138, 140]],
#
#         [[117,  98,  91],
#          [113,  94,  93],
#          [127, 109, 115],
#          ...,
#          [161, 148, 148],
#          [169, 152, 149],
#          [164, 146, 143]],
#
#         [[120, 103, 105],
#          [117, 104, 103],
#          [119, 110, 109],
#          ...,
#          [164, 151, 159],
#          [166, 151, 157],
#          [163, 148, 154]],
#
#         ...,
#
#         [[ 72,  39,  37],
#          [ 74,  41,  41],
#          [ 76,  44,  45],
#          ...,
#          [ 23,  18,  40],
#          [ 22,  20,  29],
#          [ 22,  20,  28]],
#
#         [[ 76,  47,  36],
#          [ 76,  45,  32],
#          [ 79,  46,  31],
#          ...,
#          [ 22,  16,  47],
#          [ 20,  20,  31],
#          [ 16,  17,  26]],
#
#         [[ 73,  48,  28],
# ...

# %%
flag, img = vid.read()

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
if flag:
    plt.imshow(img)
# BGR color format main picture

# %%
if flag:
    plt.imshow(img[:, :, ::-1])
# RGB  color format main picture

# %%
plt.imshow(img[:, ::-1, ::-1])

# %%
ord('\n')
# Out:
# 10

# %%
ord('\r')
# Out:
# 13

# %%
ord('a')
# Out:
# 97

# %%
vid = cv2.VideoCapture(0)
flag, img = vid.read()

for i in range(100):
    flag, img = vid.read()
    if flag:
        # img[:,:,::-1]
        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('x'):
            break
        sleep(0.1)
vid.release()
cv2.destroyAllWindows()
# Out:
# -1

# %%
import cv2
import numpy as np
from time import sleep
import random
import math
# color = (math.floor(random.random()*256),math.floor(random.random()*256),math.floor(random.random()*256))

# face descriptor
fd = cv2.CascadeClassifier(cv2.data.haarcascades +
                           'haarcascade_frontalface_default.xml')

vid = cv2.VideoCapture(0)
# rand_color = tuple(np.random.random(range(256),k=3))
rand_color = tuple(np.random.choice(range(256), size=3))
while True:
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # th , img_binary = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY)
        # img[:,:,::-1] color to rgb

        # x1,y1,w,h = (200,400,300,400)

        faces = fd.detectMultiScale(img_gray, 1.1, 5)

        for x1, y1, w, h in faces:
            # img_cropped = img[y1:y1+h,x1:x1+w ,:] #row y , column x
            cv2.rectangle(img, pt1=(x1, y1), pt2=(x1+w, y1+h),
                          color=tuple(np.random.randint(
                              size=3, low=0, high=255, dtype='int').tolist()),
                          #   (math.floor(random.random()*256),math.floor(random.random()*256),math.floor(random.random()*256)),
                          thickness=6)

        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('x'):  # ctrl + Enter for ord 10
            break
    else:
        break
    sleep(0.1)
vid.release()
cv2.destroyAllWindows()

# %%
rand_color = tuple(np.random.randint(
    size=3, low=0, high=255, dtype='int').tolist())
rand_color
# Out:
# (205, 185, 57)

# %%
cv2.destroyAllWindows()

# %%
vid.release()

# %%
color = tuple(np.random.choice(range(256), size=3))
color
# Out:
# (63, 140, 197)

# %%
import numpy as np
np.random.choice(range(256), size=3)
# Out:
# array([122, 115,  74])

# %%
import random
import math
# (math.floor(random.random()*256),
#  math.floor(random.random()*256), math.floor(random.random()*256))

# %%
(math.floor(random.random()*256),)*3
# Out:
# (108, 108, 108)

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Smile Detection

# %%
# Smile detection
import cv2
from time import sleep

# face descriptor
fd = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
sd = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_smile.xml')


vid = cv2.VideoCapture(0)

while True:
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        faces = fd.detectMultiScale(
            image=img_gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(180, 180)
        )

        for x1, y1, w, h in faces:

            # shallow copy new array will be gernerated
            face = img_gray[y1:y1+h, x1:x1+w].copy()
            cv2.rectangle(image=img, pt1=(x1, y1), pt2=(x1+w, y1+h),
                         color=(0, 0, 255),
                         thickness=6)

            smiles = sd.detectMultiScale(
                image=face,
                scaleFactor=1.1,
                minNeighbors=5,
                minSize=(50, 50))

            if len(smiles) == 1:
                xs, ys, ws, hs = smiles[0]
                cv2.rectangle(image=img, pt1=(x1+xs, y1+ys), pt2=(x1+xs+ws, y1+ys+hs),
                              color=(0, 255, 0),
                              thickness=2)

        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('x'):  # ctrl + Enter for ord 10
            break
    else:
        break
    sleep(0.1)
vid.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Face Detect And Capture

# %%
# face detect and capture

import cv2
from time import sleep

# face descriptor
fd = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
sd = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_smile.xml')


vid = cv2.VideoCapture(0)
seq =0 
captured = False

while not captured :
    flag, img = vid.read()
    if flag:
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        faces = fd.detectMultiScale(
            img_gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(180, 180)
        )

        for x1, y1, w, h in faces:
            face = img_gray[y1:y1+h, x1:x1+w].copy()  # shallow copy new array will be gernerated
            smiles = sd.detectMultiScale(face,1.1,5,minSize=(50, 50))

            if len(smiles) == 1:
                seq += 1
                if seq == 5:
                    sleep(1)
                    captured = cv2.imwrite('image3.png',img)
                    break
            else:
                seq = 0 
        cv2.imshow('Preview', img)
        key = cv2.waitKey(1)
        if key == ord('x'):     
            break
    else:
        break
    sleep(0.1)
vid.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Day 13

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import skimage as ski

# %%
img1 = cv2.imread('spiderman.png')
img2 = cv2.imread('clock2.jpg')
img1 = img1[160:160+234,100:100+373,:]

# %%
img1.shape,img2.shape
# Out:
# ((234, 373, 3), (234, 373, 3))

# %%
def showimg(im):
    plt.imshow(im[:,:,::-1])
    plt.show()


def imshow(im):
    cv2.imshow('Preview' , im)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
imshow(img1)

# %%
imshow(img2)

# %%
added = cv2.add(img1,img2)
# imshow(added)
showimg(added)

# %%
subtracted = cv2.subtract(img1,img2)
showimg(subtracted)

# %%
np.ones(img2.shape).dtype
# Out:
# dtype('float64')

# %%
img2_1 = cv2.multiply(img2, 5* np.ones(img2.shape).astype('uint8'))
showimg(img2_1)

# %%
img2_2 = cv2.divide(img2, 2* np.ones(img2.shape).astype('uint8'))
showimg(img2_2)

# %%
# alpha = contrast , beta = brightness
img2_3 = cv2.convertScaleAbs(img2 ,alpha=5,beta=82)
showimg(img2_3)

# %%
img2_4 = cv2.resize(img2 ,(400,400) ,interpolation=cv2.INTER_CUBIC)
print(img2_4.shape)
showimg(img2_4)
# Out:
# (400, 400, 3)

# %%
img2_5 = cv2.resize(img2 ,None ,fx = 2, fy=0.5,interpolation=cv2.INTER_CUBIC)
print(img2_5.shape)
showimg(img2_5)
# Out:
# (117, 746, 3)

# %%
# from skimage.transform import rotate 
img2_6 = ski.transform.rotate(img2 , angle=-45,resize=True)
showimg(img2_6)

# %% [markdown]
# # Animation

# %%
import cv2
from skimage.transform import rotate 
from time import sleep


img1 = cv2.imread('spiderman-400.png')
repeat = True
while repeat:
    for i in range(360):
        i = rotate(img1,angle=i,resize=True)
        cv2.imshow('Preview',i)
        key = cv2.waitKey(1)
        if key == ord('q'):
            repeat= False
            break
    sleep(0.1)
cv2.destroyAllWindows()

# %%
#because img in BGR
im_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
im_red = img1[:,:,2]
im_green = img1[:,:,1]
im_blue = img1[:,:,0]

# %%
import cmake

# %%
cmake.__version__
# Out:
# '3.26.3'

# %% [markdown]
# # blue color detection

# %%
import cv2,skimage
vid = cv2.VideoCapture(0)
while True:
    flag,img = vid.read()  #BGR
    if flag:
        gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        blue_img = cv2.subtract(img[:,:,-1],gray_img)
        th , blue_binary = cv2.threshold(blue_img,55,255,cv2.THRESH_BINARY)
        blue_binary2 = skimage.morphology.remove_small_objects(blue_binary.astype(bool),134)
        strel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(10,10))
        blue_binary3 = cv2.dilate(blue_binary2.astype('uint8'),strel,iterations=1)
        blue_binary4 = skimage.morphology.remove_small_holes(blue_binary3.astype(bool),5000)
        labels = skimage.measure.label(blue_binary4)
        rp = skimage.measure.regionprops(labels,blue_binary4)

        img_orig = img.copy()

        if len(rp)>0:
            (y1,x1,y2,x2) = rp[0].bbox
            cv2.rectangle(img_orig,pt1=(x1,y1),pt2=(x2,y2),color=(255,255,0),thickness=10)
        cv2.imshow('preview',img_orig)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
cv2.destroyAllWindows()
vid.release()

# %%
import cv2
import face_recognition

# Load a sample image
image = cv2.imread("many-faces.jpg")

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

# Print the number of faces found
print("Found", len(face_locations), "faces in the image.")
# Out:
# Found 11 faces in the image.

# %% [markdown]
# # FACE RECOGNITION

# %% [markdown]
# #### face capture

# %%
import cv2
vid = cv2.VideoCapture(0)
fd = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

frame_count = 0
name = input("name input")
notCaptured = True
while True:
    flag,img = vid.read()
    if flag:
        faces = fd.detectMultiScale(
            cv2.cvtColor(img,cv2.COLOR_BGR2GRAY),scaleFactor=1.1,minNeighbors=5,minSize=(50,50))
        if len(faces) ==1:
            x,y,w,h = faces[0]
            img_face = img[y:y+h,x:x+w,:].copy()
            cv2.imwrite(f'img_folder\\{name}_{frame_count}.png',img_face)
            frame_count+=1
            if frame_count==20:
                break
        cv2.imshow('preview',img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
cv2.destroyAllWindows()
vid.release()

# %% [markdown]
# #### database created

# %%
import cv2
import face_recognition as fr
import pandas as pd

vid = cv2.VideoCapture(0)
fd = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

try:
    face_db = pd.read_csv('faces_data.tsv',sep='\t',index_col=0)
    data ={
        'name':face_db['name'].values.tolist(),
        'encoding':face_db['encoding'].values.tolist()
    }
except Exception as e:
    print(e)
    data = {'name':[],'encoding':[]}

names = data['name']
enc = data['encoding']

frame_count = 0
frame_limit = 1
name = input("name input")
while True:
    flag,img = vid.read()
    if flag:
        faces = fd.detectMultiScale(
            cv2.cvtColor(img,cv2.COLOR_BGR2GRAY),scaleFactor=1.1,minNeighbors=5,minSize=(50,50))
        if len(faces) ==1:
            x,y,w,h = faces[0]
            img_face = img[y:y+h,x:x+w,:].copy()
            img_face = cv2.resize(img_face,(400,400),interpolation=cv2.INTER_CUBIC)
            face_encoding = fr.face_encodings(img_face) 
            if len(face_encoding) == 1:
                enc.append(face_encoding[0].tolist())
                names.append(name)
                frame_count+=1
                if frame_count==frame_limit:
                    data = {'name':names , 'encoding':enc}
                    pd.DataFrame(data).to_csv('faces_data.tsv' ,sep='\t')
                    break
        cv2.imshow('preview',img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
cv2.destroyAllWindows()
vid.release()
# Out:
# [Errno 2] No such file or directory: 'faces_data.tsv'

# %%
type(face_encoding[0])
# Out:
# numpy.ndarray

# %%
face_encoding[0]
# Out:
# array([-0.19791757,  0.14250161,  0.05558575, -0.03887042, -0.06051871,
#        -0.11295898,  0.05019973, -0.07210367,  0.16434917,  0.0273441 ,
#         0.24146996,  0.00496688, -0.22145069, -0.16183631,  0.05028664,
#         0.11998911, -0.10643727, -0.07783745, -0.0601702 , -0.12005307,
#         0.00733625,  0.01239739, -0.00352244,  0.05392063, -0.06401584,
#        -0.26049781, -0.08588782, -0.14201725, -0.0007237 , -0.07166749,
#        -0.0558689 ,  0.07510921, -0.18115541, -0.15716788,  0.05261504,
#         0.06320333, -0.03064785, -0.01602906,  0.17266707, -0.00626461,
#        -0.11192686, -0.06894195,  0.070061  ,  0.24420947,  0.18641201,
#         0.00527556, -0.00591795, -0.01543402,  0.15649818, -0.14457743,
#         0.05171591,  0.14469595,  0.17053232,  0.02917116,  0.10044374,
#        -0.20252131,  0.02200256,  0.07387072, -0.19994617,  0.027844  ,
#         0.03494843, -0.13043684, -0.12151782, -0.04620976,  0.1898157 ,
# ...

# %%
(face_encoding[0]).shape
# Out:
# (128,)

# %%
names = []
enc = []

# %%
names.append(name)
enc.append(face_encoding[0])

# %%
data = {'name':names , 'encoding':enc}

# %%
pd.DataFrame(data).to_csv('faces_data.csv')

# %%
face_data = pd.read_csv('faces_data.csv' , index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7888\179951268.py in <module>
# ----> 1 face_data = pd.read_csv('faces_data.csv' , index_col=0)
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
face_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7888\2846258111.py in <module>
# ----> 1 face_data
#
# NameError: name 'face_data' is not defined

# %%
cv2.destroyAllWindows()
vid.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10784\3546363359.py in <module>
# ----> 1 cv2.destroyAllWindows()
#       2 vid.release()
#
# NameError: name 'cv2' is not defined

# %% [markdown]
# # tsv file creation

# %%
import cv2
import face_recognition as fr
import pandas as pd

vid = cv2.VideoCapture(0)
fd = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

try:
    face_db = pd.read_csv('faces_data.tsv',sep='\t')
    data ={
        'name':face_db['name'].values.tolist(),
        'encoding':face_db['encoding'].values.tolist()
    }
except Exception as e:
    print(e)
    data = {'name':[],'encoding':[]}

names = data['name']
enc = data['encoding']

frame_count = 0
frame_limit = 1
name = input("name input")
while True:
    flag,img = vid.read()
    if flag:
        faces = fd.detectMultiScale(
            cv2.cvtColor(img,cv2.COLOR_BGR2GRAY),scaleFactor=1.1,minNeighbors=5,minSize=(50,50))
        if len(faces) ==1:
            x,y,w,h = faces[0]
            img_face = img[y:y+h,x:x+w,:].copy()
            img_face = cv2.resize(img_face,(400,400),interpolation=cv2.INTER_CUBIC)
            face_encoding = fr.face_encodings(img_face) 
            if len(face_encoding) == 1:
                enc.append(face_encoding[0].tolist())
                names.append(name)
                frame_count+=1
                cv2.putText(img,str(frame_count),(50,50),cv2.FONT_HERSHEY_SIMPLEX,1.5,
                                    (0,0,255),8)
                if frame_count==frame_limit:
                    data = {'name':names , 'encoding':enc}
                    pd.DataFrame(data).to_csv('faces_data.tsv' ,sep='\t')
                    break
        cv2.imshow('preview',img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
cv2.destroyAllWindows()
vid.release()

# %% [markdown]
# #### code face recognition

# %%
import cv2
import face_recognition as fr
import pandas as pd
import numpy as np

vid = cv2.VideoCapture(0)
fd = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

try:
    face_db = pd.read_csv('faces_data.tsv',sep='\t')   #index_col=0
    data ={
        'name':face_db['name'].values.tolist(),
        'encoding':face_db['encoding'].values.tolist()
    }
except Exception as e:
    print(e)
    data = {'name':[],'encoding':[]}


names = data['name']
enc = data['encoding']

frame_count = 0
frame_limit = 1
captured = True
while captured:
    flag,img = vid.read()
    if flag:
        faces = fd.detectMultiScale(
            cv2.cvtColor(img,cv2.COLOR_BGR2GRAY),scaleFactor=1.1,minNeighbors=5,minSize=(50,50))
        
        if len(faces) ==1:
            x,y,w,h = faces[0]
            img_face = img[y:y+h,x:x+w,:].copy()
            img_face = cv2.resize(img_face,(400,400),interpolation=cv2.INTER_CUBIC)
            face_encoding = fr.face_encodings(img) 

            if len(face_encoding) == 1:
                print('Recognition will start')
                for index,enc_value in enumerate(data['encoding']):
                    matched = fr.compare_faces(face_encoding,np.array(eval(enc_value)),tolerance=0.6)
                    print(matched)
                    if matched[0] == True:
                        print(data['name'][index])
                        cv2.putText(img,data['name'][index],(50,50),cv2.FONT_HERSHEY_SIMPLEX,1.5,
                                    (0,0,255),8)
                        break
                    
        cv2.imshow('preview',img)
        key = cv2.waitKey(1)
        if key == ord('q'):
            break
cv2.destroyAllWindows()
vid.release()
# Out:
# Recognition will start
# [False]
# [False]
# Recognition will start
# [False]
# [True]
# animesh
# Recognition will start
# [False]
# [True]
# animesh
# Recognition will start
# [False]
# [True]
# animesh
# Recognition will start
# [False]
# [True]
# animesh
# Recognition will start
# [False]
# [True]
# animesh
# Recognition will start
# [False]
# [True]
# animesh
# Recognition will start
# [False]
# [False]
# Recognition will start
# [False]
# [True]
# animesh

# %%
(data['encoding'][0]).split(',')
# Out:
# ['[-0.19791756570339203',
#  ' 0.1425016075372696',
#  ' 0.055585749447345734',
#  ' -0.038870420306921005',
#  ' -0.06051870808005333',
#  ' -0.11295897513628006',
#  ' 0.0501997284591198',
#  ' -0.07210367172956467',
#  ' 0.16434916853904724',
#  ' 0.027344102039933205',
#  ' 0.24146996438503265',
#  ' 0.0049668848514556885',
#  ' -0.22145068645477295',
#  ' -0.16183631122112274',
#  ' 0.050286635756492615',
#  ' 0.11998911201953888',
#  ' -0.10643726587295532',
#  ' -0.07783745229244232',
#  ' -0.06017020344734192',
#  ' -0.12005306780338287',
#  ' 0.007336245384067297',
#  ' 0.012397389858961105',
#  ' -0.003522436134517193',
#  ' 0.05392063409090042',
#  ' -0.06401583552360535',
#  ' -0.2604978084564209',
#  ' -0.08588781952857971',
#  ' -0.14201724529266357',
#  ' -0.0007236981764435768',
#  ' -0.07166749238967896',
#  ' -0.05586890131235123',
#  ' 0.07510920614004135',
#  ' -0.18115541338920593',
#  ' -0.15716788172721863',
#  ' 0.05261503532528877',
# ...

# %%
for index,enc_value in enumerate(data['encoding']):
                    # print(enc_value)
                    print(index)
                    matched = fr.compare_faces(face_encoding,np.array(eval(enc_value)))
                    print(matched)
                    if matched == True:
                        break
# Out:
# 0
# []

# %%
face_encoding
# Out:
# [array([-0.10803172,  0.05684577,  0.03372109, -0.02698288, -0.11652806,
#         -0.09720148, -0.06001861, -0.02914545,  0.09993204, -0.00638273,
#          0.21289852,  0.00132489, -0.2057254 , -0.08724955, -0.01316571,
#          0.1218924 , -0.14974655, -0.10036239, -0.09995639, -0.09381788,
#          0.04325071,  0.01242787,  0.04539258,  0.04007366, -0.10665297,
#         -0.37195781, -0.12380639, -0.11225564,  0.03008043, -0.04012104,
#         -0.0314909 ,  0.055926  , -0.16235773, -0.09527574,  0.03966858,
#          0.08204283, -0.03634446, -0.09759235,  0.24379466,  0.00974696,
#         -0.1342511 ,  0.0423741 ,  0.06353899,  0.24500047,  0.21815141,
#          0.06486278,  0.0603935 ,  0.01741198,  0.11197847, -0.21680158,
#          0.09414604,  0.16583773,  0.09782258,  0.04443803,  0.13046433,
#         -0.16038263,  0.01921579,  0.17371292, -0.22891121,  0.05672268,
#         -0.04348345, -0.08394708, -0.02096486, -0.08445529,  0.23666514,
# ...

# %%
for index,enc_value in enumerate(data['encoding']):
    print(type(eval(enc_value)) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10784\3481578105.py in <module>
# ----> 1 for index,enc_value in enumerate(data['encoding']):
#       2     print(type(eval(enc_value)) )
#       3
#       4
#
# NameError: name 'data' is not defined

# %%
(data['encoding'][0])
# Out:
# '[-0.12548716366291046, 0.06882688403129578, 0.018537353724241257, -0.020813705399632454, -0.13092075288295746, -0.11951247602701187, -0.0240322258323431, -0.038491830229759216, 0.11118454486131668, -0.030147641897201538, 0.2504219710826874, 0.017085736617445946, -0.2066013664007187, -0.10206560790538788, 0.015954934060573578, 0.12259895354509354, -0.1356029063463211, -0.08067579567432404, -0.08881375193595886, -0.07645677030086517, -0.021604521200060844, -0.03162774443626404, 0.016677282750606537, 0.07379680126905441, -0.1020742654800415, -0.2670780122280121, -0.11550204455852509, -0.07299776375293732, 0.03285844996571541, -0.07312647998332977, -0.01017416175454855, 0.04351333901286125, -0.20748600363731384, -0.117338165640831, 0.05031072348356247, 0.061423107981681824, -0.06080249696969986, -0.07076855003833771, 0.26940158009529114, 0.007486567832529545, -0.1381533294916153, -0.0187702476978302, 0.03100496158003807, 0.25970563292503357, 0.20443665981292725, 0.03771854192018509, -0.
# ...

# %%
counter =0
for index,enc_value in enumerate(data['encoding']):
    counter += 1
    print(np.array(eval(enc_value)))
# index,enc_value[0]
print(counter)
# Out:
# [-6.78448603e-02  5.38744926e-02  4.10513654e-02  3.84443700e-02
#  -9.06205401e-02 -1.18173324e-01 -7.52378255e-02 -3.93096209e-02
#   1.15957141e-01 -7.58947507e-02  2.23038301e-01  2.25286968e-02
#  -1.84188709e-01  3.52641079e-03 -5.29666878e-02  9.17326361e-02
#  -1.51736259e-01 -4.60765138e-02 -1.40764937e-01 -1.40573382e-01
#   1.56397047e-03  7.28929322e-03  2.40686312e-02  1.96421891e-02
#  -8.61030146e-02 -2.41205901e-01 -1.39713213e-01 -1.01370022e-01
#   8.92282575e-02 -6.48185089e-02 -3.34831476e-02  4.84910747e-03
#  -1.92301363e-01 -8.59313533e-02 -1.23327076e-02 -9.17820912e-03
#  -4.62501645e-02 -1.09331504e-01  2.71255553e-01  3.16507593e-02
#  -1.31628752e-01  2.18353793e-03  5.02638742e-02  2.68004864e-01
#   2.71242440e-01 -1.13903033e-02 -5.63908368e-04 -2.33760215e-02
#   1.01769052e-01 -2.62613744e-01  3.99666876e-02  2.20939055e-01
#   7.31108859e-02  1.22455403e-01  6.43047541e-02 -1.58308417e-01
# ...

# %%
cv2.destroyAllWindows()
vid.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10784\3546363359.py in <module>
# ----> 1 cv2.destroyAllWindows()
#       2 vid.release()
#
# NameError: name 'cv2' is not defined
